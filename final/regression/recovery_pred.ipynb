# %%
import pandas as pd

# %%
df = pd.read_csv("../data/sec_timeline_scaled_recovery_rate.csv")

# %%
df.head()
# Out:
#    term  emp_length  annual_inc       dti  delinq_2yrs  fico_avg  \
# 0     0    0.272727    0.578659  0.034688            1  0.512129
# 1     1    1.000000    0.626931  0.124273            1  0.053908
# 2     0    0.000000    0.598518  0.068131            0  0.862534
# 3     0    0.545455    0.584349  0.028188            0  0.215633
# 4     0    1.000000    0.594195  0.106040            0  0.080863
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  home_ownership_OWN  \
# 0               0  0.155556        0   0.544497  ...               False
# 1               1  0.266667        0   0.659641  ...               False
# 2               0  0.200000        0   0.559936  ...               False
# 3               0  0.077778        1   0.598166  ...               False
# 4               0  0.211111        0   0.658498  ...               False
#
#    home_ownership_RENT  verification_status_Source Verified  \
# 0                False                                False
# 1                False                                False
# 2                False                                False
# 3                False                                False
# 4                False                                 True
#
#    verification_status_Verified  loan_status     grade  sub_grade  loan_amnt  \
# 0                          True            0  0.000000   0.117647   0.566905
# 1                          True            1  0.666667   0.676471   0.875639
# 2                         False            1  0.000000   0.029412   0.790812
# 3                         False            0  0.166667   0.205882   0.501238
# 4                         False            0  0.166667   0.205882   0.841755
#
#    int_rate  recovery_rate
# 0    0.0797       0.993053
# 1    0.2499       0.210523
# 2    0.0707       0.663020
# 3    0.1042       0.976153
# 4    0.0999       1.000000
#
# [5 rows x 49 columns]

# %%
############### Library ###############
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error
import joblib

############### Data ###############
file_path = '../data/sec_timeline_scaled_recovery_rate.csv'
df = pd.read_csv(file_path)

# X와 y 분리
y = df['recovery_rate']
X = df.drop('recovery_rate', axis=1)

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# Train, Valid, Test 셋 분할 (대략 64% / 16% / 20%)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=RANDOM_SEED)

############### Feature Selection Functions ###############
# 단일 validation 셋을 이용한 forward search
def forward_search(model, X_train, y_train, X_valid, y_valid, max_features=None):
    if max_features is None:
        max_features = X_train.shape[1]
    
    features = []
    remaining_features = list(X_train.columns)
    best_score = float('inf')
    scores_history = []
    feature_history = []
    
    for i in range(max_features):
        best_new_score = float('inf')
        best_feature = None
        
        for feature in remaining_features:
            current_features = features + [feature]
            # 학습 및 예측
            model.fit(X_train[current_features], y_train)
            y_valid_pred = model.predict(X_valid[current_features])
            current_score = mean_absolute_error(y_valid, y_valid_pred)
            
            if current_score < best_new_score:
                best_new_score = current_score
                best_feature = feature
        
        if best_new_score < best_score:
            features.append(best_feature)
            remaining_features.remove(best_feature)
            best_score = best_new_score
            scores_history.append(best_score)
            feature_history.append(best_feature)
            print(f"Forward Search - Added feature: {best_feature}, MAE: {best_score:.4f}, Total features: {len(features)}")
        else:
            break
            
    return features, scores_history, feature_history

# 단일 validation 셋을 이용한 backward search
def backward_search(model, X_train, y_train, X_valid, y_valid, min_features=1):
    features = list(X_train.columns)
    best_score = float('inf')
    scores_history = []
    removed_features = []
    
    # 초기 성능 계산 (전체 feature 사용)
    model.fit(X_train[features], y_train)
    y_valid_pred = model.predict(X_valid[features])
    best_score = mean_absolute_error(y_valid, y_valid_pred)
    
    while len(features) > min_features:
        best_new_score = float('inf')
        worst_feature = None
        
        for feature in features:
            current_features = [f for f in features if f != feature]
            model.fit(X_train[current_features], y_train)
            y_valid_pred = model.predict(X_valid[current_features])
            current_score = mean_absolute_error(y_valid, y_valid_pred)
            
            if current_score < best_new_score:
                best_new_score = current_score
                worst_feature = feature
        
        if best_new_score <= best_score:
            features.remove(worst_feature)
            best_score = best_new_score
            scores_history.append(best_score)
            removed_features.append(worst_feature)
            print(f"Backward Search - Removed feature: {worst_feature}, MAE: {best_score:.4f}, Remaining features: {len(features)}")
        else:
            break
            
    return features, scores_history, removed_features

############### Model Training Function ###############
def train_models(X_train, y_train, X_valid, y_valid, method='selection'):
    """
    Train regression models using specified feature selection method.
    method: 'selection' (전체 feature 사용), 'forward', or 'backward'
    """
    # 기본 회귀 모델들
    base_learners = [
        ('ridge', Ridge()),
        ('lasso', Lasso()),
        ('elasticnet', ElasticNet()),
    ]
    
    model_results = {}
    # 반드시 포함해야 하는 도메인 feature
    domain_features = ['emp_length', 'dti', 'revol_util', 'fico_avg']
    
    # 결과 저장 폴더 (모델 저장 경로: "./model")
    output_dir = "./model"
    os.makedirs(output_dir, exist_ok=True)
    
    for name, model in base_learners:
        print(f"\nProcessing {name} model using {method} method...")
        try:
            model_results[name] = {
                'model_type': 'Linear',
                'model_name': name,
                'selected_features': None,
                'n_features': None,
                'mae_score': None
            }
            
            # Feature selection 적용
            if method == 'forward':
                selected_features, _, feature_history = forward_search(model, X_train, y_train, X_valid, y_valid)
                model_results[name]['feature_order'] = ', '.join(feature_history)
            elif method == 'backward':
                selected_features, _, removed_features = backward_search(model, X_train, y_train, X_valid, y_valid)
                model_results[name]['feature_order'] = ', '.join(removed_features)
            else:  # 'selection' 기본: 전체 feature 사용
                selected_features = X_train.columns.tolist()
            
            # 도메인 feature 반드시 포함
            selected_features = list(set(domain_features) | set(selected_features))
            # (선택된 feature가 20개를 초과하면 도메인 feature 우선 + 앞쪽 일부 선택)
            if len(selected_features) > 20:
                non_domain = [feat for feat in selected_features if feat not in domain_features]
                selected_features = domain_features + non_domain[:(20 - len(domain_features))]
            
            model_results[name]['selected_features'] = ', '.join(selected_features)
            model_results[name]['n_features'] = len(selected_features)
            
            # 선택된 feature로 학습
            X_train_sel = X_train[selected_features]
            X_valid_sel = X_valid[selected_features]
            model.fit(X_train_sel, y_train)
            y_valid_pred = model.predict(X_valid_sel)
            mae = mean_absolute_error(y_valid, y_valid_pred)
            model_results[name]['mae_score'] = mae
            
            # 모델 저장 (파일명: recovery_pred_<모델이름>.pkl)
            save_path = os.path.join(output_dir, f"recovery_pred_{name}.pkl")
            joblib.dump(model, save_path)
            print(f"{name} model saved to {save_path} (MAE: {mae:.4f})")
            
        except Exception as e:
            print(f"Error processing {name}: {str(e)}")
            continue
            
    results_df = pd.DataFrame.from_dict(model_results, orient='index')
    results_df['method'] = method
    results_df.to_csv(os.path.join(output_dir, f"regression_models_results_{method}.csv"), index=False)
    return results_df

############### 모델 학습 실행 ###############
# 여러 방법('selection', 'forward', 'backward')에 대해 모델 학습
for method in ['selection', 'forward', 'backward']:
    print(f"\nTraining models with {method} method...")
    results = train_models(X_train, y_train, X_valid, y_valid, method=method)
    print(f"\nResults for {method} method:")
    print(results)
# Out:
# Training models with selection method...
#
# Processing ridge model using selection method...
# ridge model saved to ./model\recovery_pred_ridge.pkl (MAE: 0.1502)
#
# Processing lasso model using selection method...
# lasso model saved to ./model\recovery_pred_lasso.pkl (MAE: 0.1754)
#
# Processing elasticnet model using selection method...
# elasticnet model saved to ./model\recovery_pred_elasticnet.pkl (MAE: 0.1754)
#
# Results for selection method:
#            model_type  model_name  \
# ridge          Linear       ridge
# lasso          Linear       lasso
# elasticnet     Linear  elasticnet
#
#                                             selected_features  n_features  \
# ridge       emp_length, dti, revol_util, fico_avg, total_a...          20
# lasso       emp_length, dti, revol_util, fico_avg, total_a...          20
# elasticnet  emp_length, dti, revol_util, fico_avg, total_a...          20
#
#             mae_score     method
# ridge        0.150152  selection
# lasso        0.175420  selection
# elasticnet   0.175420  selection
#
# Training models with forward method...
#
# Processing ridge model using forward method...
# Forward Search - Added feature: loan_status, MAE: 0.0856, Total features: 1
# Forward Search - Added feature: term, MAE: 0.0782, Total features: 2
# Forward Search - Added feature: int_rate, MAE: 0.0756, Total features: 3
# Forward Search - Added feature: sub_grade, MAE: 0.0733, Total features: 4
# Forward Search - Added feature: bc_util, MAE: 0.0722, Total features: 5
# Forward Search - Added feature: num_rev_tl_bal_gt_0, MAE: 0.0721, Total features: 6
# Forward Search - Added feature: annual_inc, MAE: 0.0719, Total features: 7
# Forward Search - Added feature: revol_util, MAE: 0.0718, Total features: 8
# Forward Search - Added feature: verification_status_Verified, MAE: 0.0718, Total features: 9
# Forward Search - Added feature: tot_hi_cred_lim, MAE: 0.0717, Total features: 10
# Forward Search - Added feature: pub_rec_bankruptcies, MAE: 0.0717, Total features: 11
# Forward Search - Added feature: tax_liens, MAE: 0.0717, Total features: 12
# Forward Search - Added feature: delinq_2yrs, MAE: 0.0716, Total features: 13
# Forward Search - Added feature: grade, MAE: 0.0716, Total features: 14
# Forward Search - Added feature: total_acc, MAE: 0.0716, Total features: 15
# Forward Search - Added feature: percent_bc_gt_75, MAE: 0.0716, Total features: 16
# Forward Search - Added feature: fico_avg, MAE: 0.0716, Total features: 17
# Forward Search - Added feature: total_rev_hi_lim, MAE: 0.0716, Total features: 18
# Forward Search - Added feature: num_bc_tl, MAE: 0.0716, Total features: 19
# Forward Search - Added feature: num_bc_sats, MAE: 0.0715, Total features: 20
# Forward Search - Added feature: num_sats, MAE: 0.0715, Total features: 21
# Forward Search - Added feature: num_op_rev_tl, MAE: 0.0715, Total features: 22
# Forward Search - Added feature: acc_now_delinq, MAE: 0.0715, Total features: 23
# Forward Search - Added feature: tot_cur_bal, MAE: 0.0715, Total features: 24
# Forward Search - Added feature: loan_amnt, MAE: 0.0715, Total features: 25
# Forward Search - Added feature: mort_acc, MAE: 0.0715, Total features: 26
# Forward Search - Added feature: avg_cur_bal, MAE: 0.0715, Total features: 27
# Forward Search - Added feature: pct_tl_nvr_dlq, MAE: 0.0715, Total features: 28
# Forward Search - Added feature: num_accts_ever_120_pd, MAE: 0.0715, Total features: 29
# Forward Search - Added feature: emp_length, MAE: 0.0714, Total features: 30
# Forward Search - Added feature: pub_rec, MAE: 0.0714, Total features: 31
# Forward Search - Added feature: home_ownership_RENT, MAE: 0.0714, Total features: 32
# Forward Search - Added feature: dti, MAE: 0.0714, Total features: 33
# Forward Search - Added feature: total_bal_ex_mort, MAE: 0.0714, Total features: 34
# Forward Search - Added feature: bc_open_to_buy, MAE: 0.0714, Total features: 35
# Forward Search - Added feature: total_il_high_credit_limit, MAE: 0.0714, Total features: 36
# Forward Search - Added feature: total_bc_limit, MAE: 0.0714, Total features: 37
# Forward Search - Added feature: home_ownership_OTHER, MAE: 0.0714, Total features: 38
# Forward Search - Added feature: inq_last_6mths, MAE: 0.0714, Total features: 39
# ridge model saved to ./model\recovery_pred_ridge.pkl (MAE: 0.0762)
#
# Processing lasso model using forward method...
# Forward Search - Added feature: term, MAE: 0.1754, Total features: 1
# lasso model saved to ./model\recovery_pred_lasso.pkl (MAE: 0.1754)
#
# Processing elasticnet model using forward method...
# Forward Search - Added feature: term, MAE: 0.1754, Total features: 1
# elasticnet model saved to ./model\recovery_pred_elasticnet.pkl (MAE: 0.1754)
#
# Results for forward method:
#            model_type  model_name  \
# ridge          Linear       ridge
# lasso          Linear       lasso
# elasticnet     Linear  elasticnet
#
#                                             selected_features  n_features  \
# ridge       emp_length, dti, revol_util, fico_avg, total_a...          20
# lasso             fico_avg, emp_length, revol_util, dti, term           5
# elasticnet        fico_avg, emp_length, revol_util, dti, term           5
#
#             mae_score                                      feature_order  \
# ridge        0.076163  loan_status, term, int_rate, sub_grade, bc_uti...
# lasso        0.175420                                               term
# elasticnet   0.175420                                               term
#
#              method
# ridge       forward
# lasso       forward
# elasticnet  forward
#
# Training models with backward method...
#
# Processing ridge model using backward method...
# Backward Search - Removed feature: num_rev_accts, MAE: 0.0714, Remaining features: 47
# Backward Search - Removed feature: verification_status_Source Verified, MAE: 0.0714, Remaining features: 46
# Backward Search - Removed feature: open_acc, MAE: 0.0714, Remaining features: 45
# Backward Search - Removed feature: home_ownership_NONE, MAE: 0.0714, Remaining features: 44
# Backward Search - Removed feature: chargeoff_within_12_mths, MAE: 0.0714, Remaining features: 43
# Backward Search - Removed feature: revol_bal, MAE: 0.0714, Remaining features: 42
# Backward Search - Removed feature: num_actv_rev_tl, MAE: 0.0714, Remaining features: 41
# Backward Search - Removed feature: home_ownership_OTHER, MAE: 0.0714, Remaining features: 40
# ridge model saved to ./model\recovery_pred_ridge.pkl (MAE: 0.0761)
#
# Processing lasso model using backward method...
# Backward Search - Removed feature: term, MAE: 0.1754, Remaining features: 47
# Backward Search - Removed feature: emp_length, MAE: 0.1754, Remaining features: 46
# Backward Search - Removed feature: annual_inc, MAE: 0.1754, Remaining features: 45
# Backward Search - Removed feature: dti, MAE: 0.1754, Remaining features: 44
# Backward Search - Removed feature: delinq_2yrs, MAE: 0.1754, Remaining features: 43
# Backward Search - Removed feature: fico_avg, MAE: 0.1754, Remaining features: 42
# Backward Search - Removed feature: inq_last_6mths, MAE: 0.1754, Remaining features: 41
# Backward Search - Removed feature: open_acc, MAE: 0.1754, Remaining features: 40
# Backward Search - Removed feature: pub_rec, MAE: 0.1754, Remaining features: 39
# Backward Search - Removed feature: revol_bal, MAE: 0.1754, Remaining features: 38
# Backward Search - Removed feature: revol_util, MAE: 0.1754, Remaining features: 37
# Backward Search - Removed feature: total_acc, MAE: 0.1754, Remaining features: 36
# Backward Search - Removed feature: acc_now_delinq, MAE: 0.1754, Remaining features: 35
# Backward Search - Removed feature: tot_cur_bal, MAE: 0.1754, Remaining features: 34
# Backward Search - Removed feature: total_rev_hi_lim, MAE: 0.1754, Remaining features: 33
# Backward Search - Removed feature: avg_cur_bal, MAE: 0.1754, Remaining features: 32
# Backward Search - Removed feature: bc_open_to_buy, MAE: 0.1754, Remaining features: 31
# Backward Search - Removed feature: bc_util, MAE: 0.1754, Remaining features: 30
# Backward Search - Removed feature: chargeoff_within_12_mths, MAE: 0.1754, Remaining features: 29
# Backward Search - Removed feature: mort_acc, MAE: 0.1754, Remaining features: 28
# Backward Search - Removed feature: num_accts_ever_120_pd, MAE: 0.1754, Remaining features: 27
# Backward Search - Removed feature: num_actv_rev_tl, MAE: 0.1754, Remaining features: 26
# Backward Search - Removed feature: num_bc_sats, MAE: 0.1754, Remaining features: 25
# Backward Search - Removed feature: num_bc_tl, MAE: 0.1754, Remaining features: 24
# Backward Search - Removed feature: num_op_rev_tl, MAE: 0.1754, Remaining features: 23
# Backward Search - Removed feature: num_rev_accts, MAE: 0.1754, Remaining features: 22
# Backward Search - Removed feature: num_rev_tl_bal_gt_0, MAE: 0.1754, Remaining features: 21
# Backward Search - Removed feature: num_sats, MAE: 0.1754, Remaining features: 20
# Backward Search - Removed feature: pct_tl_nvr_dlq, MAE: 0.1754, Remaining features: 19
# Backward Search - Removed feature: percent_bc_gt_75, MAE: 0.1754, Remaining features: 18
# Backward Search - Removed feature: pub_rec_bankruptcies, MAE: 0.1754, Remaining features: 17
# Backward Search - Removed feature: tax_liens, MAE: 0.1754, Remaining features: 16
# Backward Search - Removed feature: tot_hi_cred_lim, MAE: 0.1754, Remaining features: 15
# Backward Search - Removed feature: total_bal_ex_mort, MAE: 0.1754, Remaining features: 14
# Backward Search - Removed feature: total_bc_limit, MAE: 0.1754, Remaining features: 13
# Backward Search - Removed feature: total_il_high_credit_limit, MAE: 0.1754, Remaining features: 12
# Backward Search - Removed feature: home_ownership_MORTGAGE, MAE: 0.1754, Remaining features: 11
# Backward Search - Removed feature: home_ownership_NONE, MAE: 0.1754, Remaining features: 10
# Backward Search - Removed feature: home_ownership_OTHER, MAE: 0.1754, Remaining features: 9
# Backward Search - Removed feature: home_ownership_OWN, MAE: 0.1754, Remaining features: 8
# Backward Search - Removed feature: home_ownership_RENT, MAE: 0.1754, Remaining features: 7
# Backward Search - Removed feature: verification_status_Source Verified, MAE: 0.1754, Remaining features: 6
# Backward Search - Removed feature: verification_status_Verified, MAE: 0.1754, Remaining features: 5
# Backward Search - Removed feature: loan_status, MAE: 0.1754, Remaining features: 4
# Backward Search - Removed feature: grade, MAE: 0.1754, Remaining features: 3
# Backward Search - Removed feature: sub_grade, MAE: 0.1754, Remaining features: 2
# Backward Search - Removed feature: loan_amnt, MAE: 0.1754, Remaining features: 1
# lasso model saved to ./model\recovery_pred_lasso.pkl (MAE: 0.1754)
#
# Processing elasticnet model using backward method...
# Backward Search - Removed feature: term, MAE: 0.1754, Remaining features: 47
# Backward Search - Removed feature: emp_length, MAE: 0.1754, Remaining features: 46
# Backward Search - Removed feature: annual_inc, MAE: 0.1754, Remaining features: 45
# Backward Search - Removed feature: dti, MAE: 0.1754, Remaining features: 44
# Backward Search - Removed feature: delinq_2yrs, MAE: 0.1754, Remaining features: 43
# Backward Search - Removed feature: fico_avg, MAE: 0.1754, Remaining features: 42
# Backward Search - Removed feature: inq_last_6mths, MAE: 0.1754, Remaining features: 41
# Backward Search - Removed feature: open_acc, MAE: 0.1754, Remaining features: 40
# Backward Search - Removed feature: pub_rec, MAE: 0.1754, Remaining features: 39
# Backward Search - Removed feature: revol_bal, MAE: 0.1754, Remaining features: 38
# Backward Search - Removed feature: revol_util, MAE: 0.1754, Remaining features: 37
# Backward Search - Removed feature: total_acc, MAE: 0.1754, Remaining features: 36
# Backward Search - Removed feature: acc_now_delinq, MAE: 0.1754, Remaining features: 35
# Backward Search - Removed feature: tot_cur_bal, MAE: 0.1754, Remaining features: 34
# Backward Search - Removed feature: total_rev_hi_lim, MAE: 0.1754, Remaining features: 33
# Backward Search - Removed feature: avg_cur_bal, MAE: 0.1754, Remaining features: 32
# Backward Search - Removed feature: bc_open_to_buy, MAE: 0.1754, Remaining features: 31
# Backward Search - Removed feature: bc_util, MAE: 0.1754, Remaining features: 30
# Backward Search - Removed feature: chargeoff_within_12_mths, MAE: 0.1754, Remaining features: 29
# Backward Search - Removed feature: mort_acc, MAE: 0.1754, Remaining features: 28
# Backward Search - Removed feature: num_accts_ever_120_pd, MAE: 0.1754, Remaining features: 27
# Backward Search - Removed feature: num_actv_rev_tl, MAE: 0.1754, Remaining features: 26
# Backward Search - Removed feature: num_bc_sats, MAE: 0.1754, Remaining features: 25
# Backward Search - Removed feature: num_bc_tl, MAE: 0.1754, Remaining features: 24
# Backward Search - Removed feature: num_op_rev_tl, MAE: 0.1754, Remaining features: 23
# Backward Search - Removed feature: num_rev_accts, MAE: 0.1754, Remaining features: 22
# Backward Search - Removed feature: num_rev_tl_bal_gt_0, MAE: 0.1754, Remaining features: 21
# Backward Search - Removed feature: num_sats, MAE: 0.1754, Remaining features: 20
# Backward Search - Removed feature: pct_tl_nvr_dlq, MAE: 0.1754, Remaining features: 19
# Backward Search - Removed feature: percent_bc_gt_75, MAE: 0.1754, Remaining features: 18
# Backward Search - Removed feature: pub_rec_bankruptcies, MAE: 0.1754, Remaining features: 17
# Backward Search - Removed feature: tax_liens, MAE: 0.1754, Remaining features: 16
# Backward Search - Removed feature: tot_hi_cred_lim, MAE: 0.1754, Remaining features: 15
# Backward Search - Removed feature: total_bal_ex_mort, MAE: 0.1754, Remaining features: 14
# Backward Search - Removed feature: total_bc_limit, MAE: 0.1754, Remaining features: 13
# Backward Search - Removed feature: total_il_high_credit_limit, MAE: 0.1754, Remaining features: 12
# Backward Search - Removed feature: home_ownership_MORTGAGE, MAE: 0.1754, Remaining features: 11
# Backward Search - Removed feature: home_ownership_NONE, MAE: 0.1754, Remaining features: 10
# Backward Search - Removed feature: home_ownership_OTHER, MAE: 0.1754, Remaining features: 9
# Backward Search - Removed feature: home_ownership_OWN, MAE: 0.1754, Remaining features: 8
# Backward Search - Removed feature: home_ownership_RENT, MAE: 0.1754, Remaining features: 7
# Backward Search - Removed feature: verification_status_Source Verified, MAE: 0.1754, Remaining features: 6
# Backward Search - Removed feature: verification_status_Verified, MAE: 0.1754, Remaining features: 5
# Backward Search - Removed feature: loan_status, MAE: 0.1754, Remaining features: 4
# Backward Search - Removed feature: grade, MAE: 0.1754, Remaining features: 3
# Backward Search - Removed feature: sub_grade, MAE: 0.1754, Remaining features: 2
# Backward Search - Removed feature: loan_amnt, MAE: 0.1754, Remaining features: 1
# elasticnet model saved to ./model\recovery_pred_elasticnet.pkl (MAE: 0.1754)
#
# Results for backward method:
#            model_type  model_name  \
# ridge          Linear       ridge
# lasso          Linear       lasso
# elasticnet     Linear  elasticnet
#
#                                             selected_features  n_features  \
# ridge       emp_length, dti, revol_util, fico_avg, total_a...          20
# lasso         fico_avg, emp_length, int_rate, revol_util, dti           5
# elasticnet    fico_avg, emp_length, int_rate, revol_util, dti           5
#
#             mae_score                                      feature_order  \
# ridge        0.076098  num_rev_accts, verification_status_Source Veri...
# lasso        0.175420  term, emp_length, annual_inc, dti, delinq_2yrs...
# elasticnet   0.175420  term, emp_length, annual_inc, dti, delinq_2yrs...
#
#               method
# ridge       backward
# lasso       backward
# elasticnet  backward
